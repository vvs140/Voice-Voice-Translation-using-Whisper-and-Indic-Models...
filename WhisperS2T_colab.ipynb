# %%
# Install Whisper
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg -y
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-_twj1n2o
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-_twj1n2o
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=4b419771628901935ac48cb36af4d450630820eaa3100deb1500f3037d255aa2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-59iduiex/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# ...

# %%
# Import
import whisper

# Load model (choose: tiny, base, small, medium, large)
model = whisper.load_model("small")
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:24<00:00, 19.7MiB/s]

# %%
# Upload audio file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63e83f77-bb2c-4ede-85d0-f0aa8af4a7e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63e83f77-bb2c-4ede-85d0-f0aa8af4a7e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Transcribe
audio_file = list(uploaded.keys())[0]
result = model.transcribe(audio_file)

# %%
print("Transcription:\n")
print(result["text"])
# Out:
# Transcription:
#
# ...

# %% [markdown]
# Method 2

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Run Whisper CLI on video/audio file
# !whisper "/content/drive/MyDrive/2F.mp4" --model small --output_dir "/content/drive/MyDrive/"
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:12.160]  Dryland farming or the dryland horticulture is the method of growing crops without irrigation
# [00:12.160 --> 00:16.600]  in areas with limited rainfall.
# [00:16.600 --> 00:26.880]  It is commonly practiced in arid regions of the world.
# [00:26.880 --> 00:38.960]  This dryland horticulture or this dryland farming is practiced in places with poor soil condition.
# [00:38.960 --> 00:50.920]  They have the soil fertility is less and frequent droughts are present and the fertilizers are
# [00:50.920 --> 00:56.800]  also less in use in this dryland farming.
# [00:56.800 --> 01:06.160]  So now there are some of the practices that are done to overcome the challenges in a dryland horticulture.
# [01:06.160 --> 01:13.000]  Soil moisture is the main limiting factor in a dryland horticulture.
# ...

# %%
# Run Whisper CLI on video/audio file
# !whisper "/content/drive/MyDrive/test_files/_og/2F.mp4" --model large --output_dir "/content/drive/MyDrive/test_files/English_og/2F"

# %%
import os



# Set your root folder (change "MyDrive" or path if needed)
root_folder = "/content/drive/MyDrive/test_files"

# Walk through all subfolders and files
for root, dirs, files in os.walk(root_folder):
    # Print folder name
    print(f"📂 {root}")

    # Print subfolders
    for d in dirs:
        print(f"   - Folder: {d}")

    # Print files
    for f in files:
        print(f"   - File: {f}")
# Out:
# 📂 /content/drive/MyDrive/test_files
#    - Folder: English_og
#    - Folder: Hindi_og
#    - Folder: tamil_og
#    - Folder: Malayalam_dubbed
#    - Folder: Kannada_dubbed
#    - Folder: Telugu_dubbed
#    - File: Naming convention.gsheet
# 📂 /content/drive/MyDrive/test_files/English_og
#    - File: 2F.mp4
#    - File: 9.mp4
# 📂 /content/drive/MyDrive/test_files/Hindi_og
#    - File: 4.mp4
#    - File: 6A.mp4
# 📂 /content/drive/MyDrive/test_files/tamil_og
#    - File: 3E.mp4
#    - File: 10C.mp4
# 📂 /content/drive/MyDrive/test_files/Malayalam_dubbed
#    - File: Chapter 2B - Knowledge on Equipment and Raw Materials Required and Their Procurement.mp4
# 📂 /content/drive/MyDrive/test_files/Kannada_dubbed
#    - File: 6D.mp4
# 📂 /content/drive/MyDrive/test_files/Telugu_dubbed
#    - File: Chapter 2D - Resistors.mp4
